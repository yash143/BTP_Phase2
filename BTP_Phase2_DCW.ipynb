# %% [markdown]
# # Importing the Dataset

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_excel(r"C:\Users\Yash Aryan\3D Objects\Data Set 1.xlsx")

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.head()
# Out:
#    Time (s)  Time (h)       temp        pH        DO% online mu   CO2 %, out  \
# 0         0  0.000000  29.347496  4.959698  82.490541       #NV       0.0415
# 1        10  0.002778  29.347496  4.959698  82.490541       #NV       0.0380
# 2        20  0.005556  29.186945  4.959681  82.478611       #NV       0.0350
# 3        30  0.008333  29.186945  4.959681  82.478611       #NV       0.0330
# 4        40  0.011111  29.186945  4.959681  82.478611       #NV       0.0310
#
#       O2 %  Unnamed: 8 offline values  Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0  20.8925         NaN       Time (h)          NaN   WCW (g/L)        Time
# 1  20.8906         NaN              0          NaN     1.14375          34
# 2  20.8906         NaN              5          NaN     3.10625          41
# 3  20.8885         NaN             10          NaN      6.4375          47
# 4  20.8862         NaN             14          NaN     17.6875          50
#
#             Unnamed: 13  Unnamed: 14 Unnamed: 15
# 0  Product titer (mg/L)          NaN         NaN
# 1                 39.52          NaN         NaN
# 2               75.3959          NaN         NaN
# 3               136.484          NaN         NaN
# 4                155.87          NaN         NaN

# %%
data.tail()
# Out:
#        Time (s)   Time (h)       temp        pH       DO% online mu  \
# 27033    270330  75.091667  26.099912  5.380420  0.133452  0.036275
# 27034    270340  75.094444  26.058284  5.379869  0.118663  0.047967
# 27035    270350  75.097222  26.610881  1.855956  0.082262  0.060307
# 27036    270360  75.100000  26.051628  1.864741  0.062859   0.07254
# 27037    270370  75.102778  25.940704  1.864006 -0.983656  0.083552
#
#         CO2 %, out       O2 %  Unnamed: 8 offline values  Unnamed: 10  \
# 27033     3.234370  16.486788         NaN            NaN          NaN
# 27034     3.234140  16.486822         NaN            NaN          NaN
# 27035     3.233905  16.486906         NaN            NaN          NaN
# 27036     3.233675  16.486956         NaN            NaN          NaN
# 27037     3.233480  16.487069         NaN            NaN          NaN
#
#       Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14 Unnamed: 15
# 27033         NaN         NaN         NaN          NaN         NaN
# 27034         NaN         NaN         NaN          NaN         NaN
# 27035         NaN         NaN         NaN          NaN         NaN
# 27036         NaN         NaN         NaN          NaN         NaN
# 27037         NaN         NaN         NaN          NaN         NaN

# %%
ana=data.copy()
len(ana)-ana['Unnamed: 11'].isnull().sum()
# Out:
# 33

# %%
ana.dropna(subset=['Unnamed: 11'],axis=0,inplace=True)

# %%
ana
# Out:
#     Time (s)  Time (h)       temp        pH        DO% online mu   CO2 %, out  \
# 0          0  0.000000  29.347496  4.959698  82.490541       #NV       0.0415
# 1         10  0.002778  29.347496  4.959698  82.490541       #NV       0.0380
# 2         20  0.005556  29.186945  4.959681  82.478611       #NV       0.0350
# 3         30  0.008333  29.186945  4.959681  82.478611       #NV       0.0330
# 4         40  0.011111  29.186945  4.959681  82.478611       #NV       0.0310
# 5         50  0.013889  29.258663  4.959681  82.478611       #NV       0.0280
# 6         60  0.016667  29.258663  4.959681  82.478611       #NV       0.0270
# 7         70  0.019444  29.258663  4.959918  82.478611       #NV       0.0240
# 8         80  0.022222  29.258663  4.959918  82.443926       #NV       0.0220
# 26  20.8399         NaN             61          NaN        1011         NaN
# 27  20.8347         NaN             63          NaN     1114.25         NaN
# 28  20.8357         NaN             66          NaN     1112.25         NaN
# 29  20.8335         NaN             68          NaN     1103.25         NaN
# 30  20.8232         NaN             70          NaN     1145.25         NaN
# 31  20.8234         NaN             72          NaN     1126.75         NaN
# 32  20.8233         NaN             75          NaN      1159.5         NaN
#
#              Unnamed: 13  Unnamed: 14                Unnamed: 15
# 0   Product titer (mg/L)          NaN                        NaN
# 1                  39.52          NaN                        NaN
# 2                75.3959          NaN                        NaN
# 3                136.484          NaN                        NaN
# 4                 155.87          NaN                        NaN
# 5                196.703          NaN                        NaN
# 6                  258.6          NaN                  mg = 0.05
# 7                550.276          NaN                     VR = 3
# 8                    NaN          NaN             yCO2 in = 0.02
# 9                    NaN          NaN  Inert values not required
# 10                   NaN          NaN                        NaN
# 11                   NaN          NaN                        NaN
# 12                   NaN          NaN                        NaN
# 13                   NaN          NaN                        NaN
# 14                   NaN          NaN                        NaN
# 15                   NaN          NaN                        NaN
# 16                   NaN          NaN                        NaN
# 17                   NaN          NaN                        NaN
# 18                   NaN          NaN                        NaN
# 19                   NaN          NaN                        NaN
# 20                   NaN          NaN                        NaN
# 21                   NaN          NaN                        NaN
# 22                   NaN          NaN                        NaN
# 23                   NaN          NaN                        NaN
# 24                   NaN          NaN                        NaN
# 25                   NaN          NaN                        NaN
# 26                   NaN          NaN                        NaN
# 27                   NaN          NaN                        NaN
# 28                   NaN          NaN                        NaN
# 29                   NaN          NaN                        NaN
# 30                   NaN          NaN                        NaN
# 31                   NaN          NaN                        NaN
# 32                   NaN          NaN                        NaN

# %% [markdown]
# # Handling Null Values

# %%
df2=data[['Time (s)', 'Time (h)', 'temp', 'pH', 'DO%', ' CO2 %, out', 'O2 %','Unnamed: 11']]

# %%
df2.head()
# Out:
#    Time (s)  Time (h)       temp        pH        DO%   CO2 %, out     O2 %  \
# 0         0  0.000000  29.347496  4.959698  82.490541       0.0415  20.8925
# 1        10  0.002778  29.347496  4.959698  82.490541       0.0380  20.8906
# 2        20  0.005556  29.186945  4.959681  82.478611       0.0350  20.8906
# 3        30  0.008333  29.186945  4.959681  82.478611       0.0330  20.8885
# 4        40  0.011111  29.186945  4.959681  82.478611       0.0310  20.8862
#
#   Unnamed: 11
# 0   WCW (g/L)
# 1     1.14375
# 2     3.10625
# 3      6.4375
# 4     17.6875

# %%
df2.dtypes
# Out:
# Time (s)         int64
# Time (h)       float64
# temp           float64
# pH             float64
# DO%            float64
#  CO2 %, out    float64
# O2 %           float64
# Unnamed: 11     object
# dtype: object

# %%
df2['Unnamed: 11'] = df2['Unnamed: 11'].replace(['WCW (g/L)'],0.0)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# 27031    270310  75.086111  26.547688  5.386409   0.132496     3.234830
# 27032    270320  75.088889  26.767729  5.380741   0.079925     3.234595
# 27033    270330  75.091667  26.099912  5.380420   0.133452     3.234370
# 27034    270340  75.094444  26.058284  5.379869   0.118663     3.234140
# 27035    270350  75.097222  26.610881  1.855956   0.082262     3.233905
# 27036    270360  75.100000  26.051628  1.864741   0.062859     3.233675
# 27037    270370  75.102778  25.940704  1.864006  -0.983656     3.233480
#
#             O2 %  Unnamed: 11
# 0      20.892500      0.00000
# 1      20.890600      1.14375
# 2      20.890600      3.10625
# 3      20.888500      6.43750
# 4      20.886200     17.68750
# 5      20.882700     44.50000
# 6      20.881100     96.68750
# 7      20.879000    187.25000
# 8      20.882000    243.50000
# 9      20.877800    236.00000
# 10     20.875600    225.00000
# 11     20.872700    284.50000
# 12     20.870500    350.00000
# 13     20.868200    437.50000
# 14     20.866200    467.00000
# 15     20.861900    470.00000
# 16     20.863000    474.00000
# 17     20.860700    517.50000
# 18     20.858600    580.00000
# 19     20.853600    645.50000
# 20     20.852400    711.50000
# 21     20.851300    712.50000
# 22     20.851300    747.50000
# 23     20.844000    808.00000
# 24     20.843000    877.00000
# 25     20.842900    922.25000
# 26     20.839900   1011.00000
# 27     20.834700   1114.25000
# 28     20.835700   1112.25000
# 29     20.833500   1103.25000
# ...          ...          ...
# 27008  16.487763          NaN
# 27009  16.487800          NaN
# 27010  16.487810          NaN
# 27011  16.487801          NaN
# 27012  16.487738          NaN
# 27013  16.487629          NaN
# 27014  16.487517          NaN
# 27015  16.487402          NaN
# 27016  16.487279          NaN
# 27017  16.487166          NaN
# 27018  16.487064          NaN
# 27019  16.486973          NaN
# 27020  16.486921          NaN
# 27021  16.486899          NaN
# 27022  16.486898          NaN
# 27023  16.486886          NaN
# 27024  16.486879          NaN
# 27025  16.486897          NaN
# 27026  16.486878          NaN
# 27027  16.486867          NaN
# 27028  16.486837          NaN
# 27029  16.486803          NaN
# 27030  16.486752          NaN
# 27031  16.486734          NaN
# 27032  16.486763          NaN
# 27033  16.486788          NaN
# 27034  16.486822          NaN
# 27035  16.486906          NaN
# 27036  16.486956          NaN
# 27037  16.487069          NaN
#
# [27038 rows x 8 columns]

# %%
df2.dtypes
# Out:
# Time (s)         int64
# Time (h)       float64
# temp           float64
# pH             float64
# DO%            float64
#  CO2 %, out    float64
# O2 %           float64
# Unnamed: 11    float64
# dtype: object

# %%
df2
# Out:
#        Time (s)   Time (h)       temp        pH        DO%   CO2 %, out  \
# 0             0   0.000000  29.347496  4.959698  82.490541     0.041500
# 1            10   0.002778  29.347496  4.959698  82.490541     0.038000
# 2            20   0.005556  29.186945  4.959681  82.478611     0.035000
# 3            30   0.008333  29.186945  4.959681  82.478611     0.033000
# 4            40   0.011111  29.186945  4.959681  82.478611     0.031000
# 5            50   0.013889  29.258663  4.959681  82.478611     0.028000
# 6            60   0.016667  29.258663  4.959681  82.478611     0.027000
# 7            70   0.019444  29.258663  4.959918  82.478611     0.024000
# 8            80   0.022222  29.258663  4.959918  82.443926     0.022000
# 27034    270340  75.094444  26.058284  5.379869   0.118663     3.234140
# 27035    270350  75.097222  26.610881  1.855956   0.082262     3.233905
# 27036    270360  75.100000  26.051628  1.864741   0.062859     3.233675
# 27037    270370  75.102778  25.940704  1.864006  -0.983656     3.233480
#
#             O2 %  Unnamed: 11
# 0      20.892500      0.00000
# 1      20.890600      1.14375
# 2      20.890600      3.10625
# 3      20.888500      6.43750
# 4      20.886200     17.68750
# 5      20.882700     44.50000
# 6      20.881100     96.68750
# 7      20.879000    187.25000
# 8      20.882000    243.50000
# 9      20.877800    236.00000
# 10     20.875600    225.00000
# 11     20.872700    284.50000
# 12     20.870500    350.00000
# 13     20.868200    437.50000
# 14     20.866200    467.00000
# 15     20.861900    470.00000
# 16     20.863000    474.00000
# 17     20.860700    517.50000
# 18     20.858600    580.00000
# 19     20.853600    645.50000
# 20     20.852400    711.50000
# 21     20.851300    712.50000
# 22     20.851300    747.50000
# 23     20.844000    808.00000
# 24     20.843000    877.00000
# 25     20.842900    922.25000
# 26     20.839900   1011.00000
# 27     20.834700   1114.25000
# 28     20.835700   1112.25000
# 29     20.833500   1103.25000
# ...          ...          ...
# 27008  16.487763          NaN
# 27009  16.487800          NaN
# 27010  16.487810          NaN
# 27011  16.487801          NaN
# 27012  16.487738          NaN
# 27013  16.487629          NaN
# 27014  16.487517          NaN
# 27015  16.487402          NaN
# 27016  16.487279          NaN
# 27017  16.487166          NaN
# 27018  16.487064          NaN
# 27019  16.486973          NaN
# 27020  16.486921          NaN
# 27021  16.486899          NaN
# 27022  16.486898          NaN
# 27023  16.486886          NaN
# 27024  16.486879          NaN
# 27025  16.486897          NaN
# 27026  16.486878          NaN
# 27027  16.486867          NaN
# 27028  16.486837          NaN
# 27029  16.486803          NaN
# 27030  16.486752          NaN
# 27031  16.486734          NaN
# 27032  16.486763          NaN
# 27033  16.486788          NaN
# 27034  16.486822          NaN
# 27035  16.486906          NaN
# 27036  16.486956          NaN
# 27037  16.487069          NaN
#
# [27038 rows x 8 columns]

# %%
df2.isnull().sum()
# Out:
# Time (s)           0
# Time (h)           0
# temp               0
# pH                 0
# DO%                0
#  CO2 %, out        0
# O2 %               0
# Unnamed: 11    27005
# dtype: int64

# %%
df2[' CO2 %, out']=df2[' CO2 %, out']*5
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['O2 %']=df2['O2 %']+1.5
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['Unnamed: 11']=df2['Unnamed: 11']*0.16
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#    Time (s)  Time (h)       temp        pH        DO%   CO2 %, out     O2 %  \
# 0         0  0.000000  29.347496  4.959698  82.490541       0.2075  22.3925
# 1        10  0.002778  29.347496  4.959698  82.490541       0.1900  22.3906
# 2        20  0.005556  29.186945  4.959681  82.478611       0.1750  22.3906
# 3        30  0.008333  29.186945  4.959681  82.478611       0.1650  22.3885
# 4        40  0.011111  29.186945  4.959681  82.478611       0.1550  22.3862
#
#    Unnamed: 11
# 0        0.000
# 1        0.183
# 2        0.497
# 3        1.030
# 4        2.830

# %%
df2.rename(columns = {'Unnamed: 11': 'wcw'}, inplace = True)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df2.rename(columns = {'wcw': 'dcw'}, inplace = True)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import missingno as msno
plt.figure(figsize=(10,5))
msno.bar(df2,figsize=(5,5))

# %%
df2.isnull().sum()
# Out:
# Time (s)           0
# Time (h)           0
# temp               0
# pH                 0
# DO%                0
#  CO2 %, out        0
# O2 %               0
# dcw            27005
# dtype: int64

# %%
plt.plot(df2['Time (h)'][:33],df2['dcw'][:33])

# %%
#new_dcw = pd.read_csv(r"C:\Users\Yash Aryan\3D Objects\new.csv")

# %%
df2
# Out:
#        Time (s)   Time (h)       temp        pH        DO%   CO2 %, out  \
# 0             0   0.000000  29.347496  4.959698  82.490541     0.207500
# 1            10   0.002778  29.347496  4.959698  82.490541     0.190000
# 2            20   0.005556  29.186945  4.959681  82.478611     0.175000
# 3            30   0.008333  29.186945  4.959681  82.478611     0.165000
# 4            40   0.011111  29.186945  4.959681  82.478611     0.155000
# 5            50   0.013889  29.258663  4.959681  82.478611     0.140000
# 6            60   0.016667  29.258663  4.959681  82.478611     0.135000
# 7            70   0.019444  29.258663  4.959918  82.478611     0.120000
# 8            80   0.022222  29.258663  4.959918  82.443926     0.110000
# 9            90   0.025000  29.258663  4.959918  82.443926     0.100000
# 10          100   0.027778  29.258663  4.959918  82.443926     0.095000
# 11          110   0.030556  29.258663  4.959918  82.443926     0.085000
# 12          120   0.033333  29.264992  4.959918  82.443926     0.072500
# 13          130   0.036111  29.264992  4.959918  82.443926     0.070000
# 14          140   0.038889  29.264992  4.959646  82.443926     0.062500
# 15          150   0.041667  29.264992  4.959646  82.443926     0.052500
# 16          160   0.044444  29.264992  4.959646  82.441919     0.047500
# 17          170   0.047222  29.264992  4.959646  82.441919     0.042500
# 18          180   0.050000  29.264992  4.959646  82.441919     0.037500
# 19          190   0.052778  29.264992  4.959646  82.441919     0.040000
# 20          200   0.055556  29.414758  4.959646  82.441919     0.032500
# 21          210   0.058333  29.414758  4.959646  82.441919     0.032500
# 22          220   0.061111  29.414758  4.960403  82.441919     0.027500
# 23          230   0.063889  29.414758  4.960403  82.441919     0.027500
# 24          240   0.066667  29.414758  4.960403  82.439650     0.022500
# 25          250   0.069444  29.414758  4.960403  82.439650     0.020000
# 26          260   0.072222  29.414758  4.960403  82.439650     0.022500
# 27          270   0.075000  29.414758  4.960403  82.439650     0.015000
# 28          280   0.077778  29.276349  4.960403  82.439650     0.017500
# 29          290   0.080556  29.276349  4.960403  82.439650     0.012500
# ...         ...        ...        ...       ...        ...          ...
# 27008    270080  75.022222  26.476454  5.431926   0.151533    16.201000
# 27009    270090  75.025000  26.539225  5.428922   0.139964    16.199350
# 27010    270100  75.027778  26.608018  5.425795   0.160217    16.197750
# 27011    270110  75.030556  26.542536  5.422582   0.161130    16.196100
# 27012    270120  75.033333  26.677363  5.417837   0.169963    16.194600
# 27013    270130  75.036111  26.618388  5.414606   0.169130    16.193175
# 27014    270140  75.038889  26.525944  5.412044   0.161454    16.191750
# 27015    270150  75.041667  26.602557  5.408340   0.166660    16.190425
# 27016    270160  75.044444  26.489067  5.404252   0.172826    16.189175
# 27017    270170  75.047222  26.586120  5.401634   0.192954    16.188075
# 27018    270180  75.050000  26.709455  5.397817   0.169498    16.187075
# 27019    270190  75.052778  26.770217  5.394113   0.203873    16.186075
# 27020    270200  75.055556  26.856426  5.389271   0.206259    16.185225
# 27021    270210  75.058333  26.883028  5.385777   0.198710    16.184325
# 27022    270220  75.061111  26.806893  5.386035   0.215582    16.183450
# 27023    270230  75.063889  26.707909  5.383319   0.221197    16.182500
# 27024    270240  75.066667  26.783030  5.381446   0.213061    16.181525
# 27025    270250  75.069444  26.857131  5.382247   0.190250    16.180500
# 27026    270260  75.072222  26.685228  5.380064   0.192957    16.179525
# 27027    270270  75.075000  26.599651  5.381387   1.386021    16.178550
# 27028    270280  75.077778  26.638677  5.395716   0.642646    16.177525
# 27029    270290  75.080556  26.261782  5.398367   0.210199    16.176500
# 27030    270300  75.083333  26.526676  5.395282   0.124181    16.175375
# 27031    270310  75.086111  26.547688  5.386409   0.132496    16.174150
# 27032    270320  75.088889  26.767729  5.380741   0.079925    16.172975
# 27033    270330  75.091667  26.099912  5.380420   0.133452    16.171850
# 27034    270340  75.094444  26.058284  5.379869   0.118663    16.170700
# 27035    270350  75.097222  26.610881  1.855956   0.082262    16.169525
# 27036    270360  75.100000  26.051628  1.864741   0.062859    16.168375
# 27037    270370  75.102778  25.940704  1.864006  -0.983656    16.167400
#
#             O2 %      dcw
# 0      22.392500    0.000
# 1      22.390600    0.183
# 2      22.390600    0.497
# 3      22.388500    1.030
# 4      22.386200    2.830
# 5      22.382700    7.120
# 6      22.381100   15.470
# 7      22.379000   29.960
# 8      22.382000   38.960
# 9      22.377800   37.760
# 10     22.375600   36.000
# 11     22.372700   45.520
# 12     22.370500   56.000
# 13     22.368200   70.000
# 14     22.366200   74.720
# 15     22.361900   75.200
# 16     22.363000   75.840
# 17     22.360700   82.800
# 18     22.358600   92.800
# 19     22.353600  103.280
# 20     22.352400  113.840
# 21     22.351300  114.000
# 22     22.351300  119.600
# 23     22.344000  129.280
# 24     22.343000  140.320
# 25     22.342900  147.560
# 26     22.339900  161.760
# 27     22.334700  178.280
# 28     22.335700  177.960
# 29     22.333500  176.520
# ...          ...      ...
# 27008  17.987763      NaN
# 27009  17.987800      NaN
# 27010  17.987810      NaN
# 27011  17.987801      NaN
# 27012  17.987738      NaN
# 27013  17.987629      NaN
# 27014  17.987517      NaN
# 27015  17.987402      NaN
# 27016  17.987279      NaN
# 27017  17.987166      NaN
# 27018  17.987064      NaN
# 27019  17.986973      NaN
# 27020  17.986921      NaN
# 27021  17.986899      NaN
# 27022  17.986898      NaN
# 27023  17.986886      NaN
# 27024  17.986879      NaN
# 27025  17.986897      NaN
# 27026  17.986878      NaN
# 27027  17.986867      NaN
# 27028  17.986837      NaN
# 27029  17.986803      NaN
# 27030  17.986752      NaN
# 27031  17.986734      NaN
# 27032  17.986763      NaN
# 27033  17.986788      NaN
# 27034  17.986822      NaN
# 27035  17.986906      NaN
# 27036  17.986956      NaN
# 27037  17.987069      NaN
#
# [27038 rows x 8 columns]

# %%
df2.drop(["dcw"],axis=1,inplace=True)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
new_dcw=pd.read_csv(r"C:\Users\Yash Aryan\3D Objects\BTP2021\new_dcw.csv")

# %%
new_dcw.drop(['Unnamed: 0'],axis=1,inplace=True)
df2['dcw']=new_dcw
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.plot(df2['Time (h)'],df2['dcw'])

# %%
temp=df2.copy()

# %% [markdown]
# from sklearn.experimental import enable_iterative_imputer
# from sklearn.impute import IterativeImputer
# from sklearn.linear_model import BayesianRidge
# from sklearn.tree import DecisionTreeRegressor
# ...
# # define imputer
# imputer = IterativeImputer(estimator=BayesianRidge(), n_nearest_features=None, imputation_order='ascending')
# imputer.fit(temp)
# temp[:] = imputer.transform(temp)

# %%
#temp['dcw']=new_dcw['DCW']

# %%
temp.isnull().sum()
# Out:
# Time (s)       0
# Time (h)       0
# temp           0
# pH             0
# DO%            0
#  CO2 %, out    0
# O2 %           0
# dcw            0
# dtype: int64

# %%
temp
# Out:
#        Time (s)   Time (h)       temp        pH        DO%   CO2 %, out  \
# 0             0   0.000000  29.347496  4.959698  82.490541     0.207500
# 1            10   0.002778  29.347496  4.959698  82.490541     0.190000
# 2            20   0.005556  29.186945  4.959681  82.478611     0.175000
# 3            30   0.008333  29.186945  4.959681  82.478611     0.165000
# 4            40   0.011111  29.186945  4.959681  82.478611     0.155000
# 5            50   0.013889  29.258663  4.959681  82.478611     0.140000
# 6            60   0.016667  29.258663  4.959681  82.478611     0.135000
# 7            70   0.019444  29.258663  4.959918  82.478611     0.120000
# 8            80   0.022222  29.258663  4.959918  82.443926     0.110000
# 9            90   0.025000  29.258663  4.959918  82.443926     0.100000
# 10          100   0.027778  29.258663  4.959918  82.443926     0.095000
# 11          110   0.030556  29.258663  4.959918  82.443926     0.085000
# 12          120   0.033333  29.264992  4.959918  82.443926     0.072500
# 13          130   0.036111  29.264992  4.959918  82.443926     0.070000
# 14          140   0.038889  29.264992  4.959646  82.443926     0.062500
# 15          150   0.041667  29.264992  4.959646  82.443926     0.052500
# 16          160   0.044444  29.264992  4.959646  82.441919     0.047500
# 17          170   0.047222  29.264992  4.959646  82.441919     0.042500
# 18          180   0.050000  29.264992  4.959646  82.441919     0.037500
# 19          190   0.052778  29.264992  4.959646  82.441919     0.040000
# 20          200   0.055556  29.414758  4.959646  82.441919     0.032500
# 21          210   0.058333  29.414758  4.959646  82.441919     0.032500
# 22          220   0.061111  29.414758  4.960403  82.441919     0.027500
# 23          230   0.063889  29.414758  4.960403  82.441919     0.027500
# 24          240   0.066667  29.414758  4.960403  82.439650     0.022500
# 25          250   0.069444  29.414758  4.960403  82.439650     0.020000
# 26          260   0.072222  29.414758  4.960403  82.439650     0.022500
# 27          270   0.075000  29.414758  4.960403  82.439650     0.015000
# 28          280   0.077778  29.276349  4.960403  82.439650     0.017500
# 29          290   0.080556  29.276349  4.960403  82.439650     0.012500
# ...         ...        ...        ...       ...        ...          ...
# 27008    270080  75.022222  26.476454  5.431926   0.151533    16.201000
# 27009    270090  75.025000  26.539225  5.428922   0.139964    16.199350
# 27010    270100  75.027778  26.608018  5.425795   0.160217    16.197750
# 27011    270110  75.030556  26.542536  5.422582   0.161130    16.196100
# 27012    270120  75.033333  26.677363  5.417837   0.169963    16.194600
# 27031  17.986734  185.520
# 27032  17.986763  185.520
# 27033  17.986788  185.520
# 27034  17.986822  185.520
# 27035  17.986906  185.520
# 27036  17.986956  185.520
# 27037  17.987069  185.520
#
# [27038 rows x 8 columns]

# %% [markdown]
# # Correlation Analysis

# %%
temp.corr()['dcw']
# Out:
# Time (s)       0.973830
# Time (h)       0.973830
# temp          -0.101904
# pH            -0.129679
# DO%           -0.759983
#  CO2 %, out    0.924922
# O2 %          -0.927434
# dcw            1.000000
# Name: dcw, dtype: float64

# %% [markdown]
# X=temp[['temp','DO%','pH',' CO2 %, out','O2 %']]
# y=temp['dcw']

# %%
import seaborn as sns
# %matplotlib inline
sns.heatmap(temp.corr())

# %% [markdown]
# # Handling outliers

# %%
from pandas.plotting import scatter_matrix
# %matplotlib inline
scatter_matrix(temp, alpha = 0.3, figsize = (14,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC8F21B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC8F5CFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC8F8D668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC8FB6CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC8FE73C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC8FE7400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9042128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC90687B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9094E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC90C2518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC90EABA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC911D278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9144908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC916CF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC919E668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC91C5CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC91F83C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC921EA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9251128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC92787B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC92A1E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC92D2518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC92F9BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC932C278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9353908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC937BF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC93AC668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC93D5CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC94053C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC942BA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9460128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC94867B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC94AFE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC94E2518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9509BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9539278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9562908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC958AF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC95BB668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC95E3CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC96143C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC963BA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC966E128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC96947B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC96BEE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC96EF518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9716BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9747278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC976F908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC979AF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC97C8668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC97F2CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC98243C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9849A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC987B128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC98A47B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC98CCE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC98FC518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9925BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9956278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC997D908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC99A7F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC99D7668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020FC9A00CF8>]],
#       dtype=object)

# %%
sns.boxplot(temp["DO%"])

# %%
sns.boxplot(temp["pH"])

# %%
outliers  = [10159,26043,26044,26045]

temp = temp.drop(temp.index[outliers]).reset_index(drop = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16, 5))
sns.boxplot(temp["dcw"],ax=ax)

# %%
fig, ax = plt.subplots(figsize=(16, 5))
sns.distplot(temp["dcw"], ax=ax)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
X=temp[['temp','DO%','pH',' CO2 %, out','O2 %']]
y=temp['dcw']

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)


print("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %% [markdown]
# # HyperParameter tuning

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    
    # TODO: Calculate the performance score between 'y_true' and 'y_predict'
    score = r2_score(y_true,y_predict)
    
    # Return the score
    return score

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import make_scorer 
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit

def fit_model(X, y):
    """ Performs grid search over the 'max_depth' parameter for a 
        decision tree regressor trained on the input data [X, y]. """
    
    # Create cross-validation sets from the training data
    cv_sets = ShuffleSplit(n_splits = 10, test_size = 0.20, random_state = 0)

    # TODO: Create a decision tree regressor object
    regressor = DecisionTreeRegressor(random_state=1001)

    # TODO: Create a dictionary for the parameter 'max_depth' with a range from 1 to 10
    params = {'max_depth': np.arange(1,50)}

    # TODO: Transform 'performance_metric' into a scoring function using 'make_scorer' 
    scoring_fnc =make_scorer(performance_metric)

    # TODO: Create the grid search cv object --> GridSearchCV()
    # Make sure to include the right parameters in the object:
    # (estimator, param_grid, scoring, cv) which have values 'regressor', 'params', 'scoring_fnc', and 'cv_sets' respectively.
    grid = GridSearchCV(regressor,params,scoring_fnc,cv=cv_sets)

    # Fit the grid search object to the data to compute the optimal model
    grid = grid.fit(X, y)

    # Return the optimal model after fitting the data
    return grid.best_estimator_

# %%
reg = fit_model(X_train, y_train)
print("Parameter 'max_depth' is {} for the optimal model.".format(reg.get_params()['max_depth']))
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass scoring=make_scorer(performance_metric) as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Parameter 'max_depth' is 15 for the optimal model.

# %%
reg.score(X_train, y_train)
# Out:
# 1.0

# %%
reg.score(X_test,y_test)
# Out:
# 0.9993765689839983

# %%
# Suppress matplotlib user warnings
# Necessary for newer version of matplotlib
import warnings
warnings.filterwarnings("ignore", category = UserWarning, module = "matplotlib")
#
# Display inline matplotlib plots with IPython
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')
###########################################

import matplotlib.pyplot as pl
import numpy as np
from sklearn.model_selection import learning_curve
from sklearn.model_selection import validation_curve
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import ShuffleSplit, train_test_split

def ModelLearning(X, y):
    """ Calculates the performance of several models with varying sizes of training data.
        The learning and testing scores for each model are then plotted. """

    # Create 10 cross-validation sets for training and testing
    cv = ShuffleSplit(n_splits = 10, test_size = 0.2, random_state = 0)

    # Generate the training set sizes increasing by 50
    train_sizes = np.rint(np.linspace(1, X.shape[0]*0.8 - 1, 9)).astype(int)

    # Create the figure window
    fig = pl.figure(figsize=(10,7))

    # Create three different models based on max_depth
    for k, depth in enumerate([16,17,18,19]):

        # Create a Decision tree regressor at max_depth = depth
        regressor = DecisionTreeRegressor(max_depth = depth)

        # Calculate the training and testing scores
        sizes, train_scores, test_scores = learning_curve(regressor, X, y, \
            cv = cv, train_sizes = train_sizes, scoring = 'r2')

        # Find the mean and standard deviation for smoothing
        train_std = np.std(train_scores, axis = 1)
        train_mean = np.mean(train_scores, axis = 1)
        test_std = np.std(test_scores, axis = 1)
        test_mean = np.mean(test_scores, axis = 1)

        # Subplot the learning curve
        ax = fig.add_subplot(2, 2, k+1)
        ax.plot(sizes, train_mean, 'o-', color = 'r', label = 'Training Score')
        ax.plot(sizes, test_mean, 'o-', color = 'g', label = 'Testing Score')
        ax.fill_between(sizes, train_mean - train_std, \
            train_mean + train_std, alpha = 0.15, color = 'r')
        ax.fill_between(sizes, test_mean - test_std, \
            test_mean + test_std, alpha = 0.15, color = 'g')

        # Labels
        ax.set_title('max_depth = %s'%(depth))
        ax.set_xlabel('Number of Training Points')
        ax.set_ylabel('Score')
        ax.set_xlim([0, X.shape[0]*0.8])
        ax.set_ylim([-0.05, 1.05])

    # Visual aesthetics
    ax.legend(bbox_to_anchor=(1.05, 2.05), loc='lower left', borderaxespad = 0.)
    fig.suptitle('Decision Tree Regressor Learning Performances', fontsize = 16, y = 1.03)
    fig.tight_layout()
    fig.show()


def ModelComplexity(X, y):
    """ Calculates the performance of the model as model complexity increases.
        The learning and testing errors rates are then plotted. """

    # Create 10 cross-validation sets for training and testing
    cv = ShuffleSplit(n_splits = 10, test_size = 0.2, random_state = 0)

    # Vary the max_depth parameter from 1 to 10
    max_depth = np.arange(1,50)

    # Calculate the training and testing scores
    train_scores, test_scores = validation_curve(DecisionTreeRegressor(), X, y, \
        param_name = "max_depth", param_range = max_depth, cv = cv, scoring = 'r2')

    # Find the mean and standard deviation for smoothing
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    # Plot the validation curve
    pl.figure(figsize=(7, 5))
    pl.title('Decision Tree Regressor Complexity Performance')
    pl.plot(max_depth, train_mean, 'o-', color = 'r', label = 'Training Score')
    pl.plot(max_depth, test_mean, 'o-', color = 'g', label = 'Validation Score')
    pl.fill_between(max_depth, train_mean - train_std, \
        train_mean + train_std, alpha = 0.15, color = 'r')
    pl.fill_between(max_depth, test_mean - test_std, \
        test_mean + test_std, alpha = 0.15, color = 'g')

    # Visual aesthetics
    pl.legend(loc = 'lower right')
    pl.xlabel('Maximum Depth')
    pl.ylabel('Score')
    pl.ylim([-0.05,1.05])
    pl.show()


def PredictTrials(X, y, fitter, data):
    """ Performs trials of fitting and predicting data. """

    # Store the predicted prices
    prices = []

    for k in range(10):
        # Split the data
        X_train, X_test, y_train, y_test = train_test_split(X, y, \
            test_size = 0.2, random_state = k)

        # Fit the data
        reg = fitter(X_train, y_train)

        # Make a prediction
        pred = reg.predict([data[0]])[0]
        prices.append(pred)

        # Result
        print("Trial {}: ${:,.2f}".format(k+1, pred))

    # Display price range
    print("\nRange in prices: ${:,.2f}".format(max(prices) - min(prices)))

# %%
ModelLearning(X, y)
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
ModelComplexity(X_train, y_train)

# %% [markdown]
# # Model Building

# %% [markdown]
# ### Decision Tree Regressor

# %%
reg2 = fit_model(X_train, y_train)
print("Parameter 'max_depth' is {} for the optimal model.".format(reg2.get_params()['max_depth']))
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass scoring=make_scorer(performance_metric) as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Parameter 'max_depth' is 15 for the optimal model.

# %%
reg2.score(X_train, y_train)
# Out:
# 1.0

# %%
reg2.score(X_test, y_test)
# Out:
# 0.9993765689839983

# %%
ModelComplexity(X_train, y_train)

# %%
pred_tree = reg2.predict(X)

# %%
#plt.plot(temp['Time (h)'],y,label='Actual Biomass',color='black')
plt.plot(temp['Time (h)'],pred_tree,label='Predicted Biomass Conc',color='black',alpha=1)
plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,'o',color='blue',label="Offline Values")


#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')
plt.xlabel("Time in Hours ")
plt.ylabel("Biomass Concentration ( g / L )")
plt.legend()
plt.title("Decision Tree Regressor")
# Out:
# Text(0.5,1,'Decision Tree Regressor')

# %% [markdown]
# ## Gradient Boost Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
model1=GradientBoostingRegressor(criterion='mse',max_depth=50)

# %%
model1.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(criterion='mse', max_depth=50)

# %%
model1.score(X_train,y_train)
# Out:
# 0.9999999992944921

# %%
model1.score(X_test,y_test)
# Out:
# 0.9994783939136549

# %%
pred = model1.predict(X_test)

# %%
# %matplotlib inline
plt.figure(figsize=(5,5))
ax2=sns.distplot(y_test,hist=False,color='r',label='actual')
sns.distplot(pred,hist=False,color='b',label='predicted',ax=ax2)
plt.title("distribution of actual and values predicted by Gradient Boosting Regressor ")
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'distribution of actual and values predicted by Gradient Boosting Regressor ')

# %%
pred2 = model1.predict(X)

# %%
plt.plot(temp['Time (h)'],pred2,label='Predicted Biomass ',color='orange')
#plt.plot(temp['Time (h)'],y,label='Actual Biomass Conc',color='orange')
plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,'-o',color='blue',label="Offline Values")
#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')

plt.xlabel("Time in Hours ")
plt.ylabel("Biomass Concentration ( g / L )")
plt.legend()
plt.title("Gradient Boosting Regressor")
# Out:
# Text(0.5,1,'Gradient Boosting Regressor')

# %% [markdown]
# ## Adaboost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor
adaboost=AdaBoostRegressor(DecisionTreeRegressor(max_depth=26),n_estimators=50)

# %%
adaboost.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=26))

# %%
adaboost.score(X_train,y_train)
# Out:
# 0.9999999342825737

# %%
adaboost.score(X_test,y_test)
# Out:
# 0.999997667246499

# %%
yhat = adaboost.predict(X_test)

# %%
# %matplotlib inline
plt.figure(figsize=(5,5))
ax2=sns.distplot(y_test,hist=False,color='r',label='actual')
sns.distplot(yhat,hist=False,color='b',label='predicted',ax=ax2)
plt.title("distribution of actual and values predicted by Adaboost Regressor ")
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'distribution of actual and values predicted by Adaboost Regressor ')

# %%
pred_ada = adaboost.predict(X)

# %%
#plt.plot(temp['Time (h)'],y,label='Actual Biomass',color='red')

plt.plot(temp['Time (h)'],pred_ada,label='Predicted Biomass Conc',color='red')
plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,'-o',color='blue',label="Offline Values")

#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')

plt.xlabel("Time in Hours ")
plt.ylabel("Biomass Concentration ( g / L )")
plt.legend()
plt.title("
# 20825    27.383786  5.487480    6.588833   0.110827  80.480004      0.9965
# 20826    27.477851  5.487289    6.591462   0.126727  80.482782      0.9975
# 20827    27.340466  5.488092    6.647611   0.140469  80.485559      0.9980
# 20828    27.449078  5.489725    6.600004   0.151955  80.488337      0.9975
# 20829    27.280438  5.489139    6.646989   0.162211  80.491115      0.9985
# 20830    27.273344  5.491281    6.758481   0.166941  80.493893      0.9985
# 20831    27.086825  5.489779    6.865013   0.171338  80.496671      0.9985
# 20832    27.138217  5.491149    6.777610   0.177677  80.499448      1.0000
# 20833    27.062315  5.491483    6.847451   0.183898  80.502226      0.9985
# 20834    26.957343  5.492753    6.937084   0.189363  80.505004      0.9975
# 20835    27.027576  5.494146    6.994090   0.193725  80.507782      0.9975
# 20836    26.948153  5.496040    6.927108   0.198314  80.510559      0.9975
# 20837    26.990793  5.496355    6.934385   0.202625  80.513337      0.9975
# 20838    26.901475  5.498700    6.971230   0.207968  80.516115      0.9965
# 20839    26.980487  5.496985    6.984090   0.214490  80.518893      0.9955
# 20840    26.400683  5.503303    7.097659   0.222275  80.521671      0.9960
# 20841    27.092721  5.495812   13.993441   0.232154  80.524448      0.9945
# 20842    26.708387  5.496397   24.778176   0.241797  80.527226      0.9945
#
#        Actual O2 Offline Values               Unnamed: 8  \
# 0        20.7762       Time (h)  DCW (Biomass Conc. g/L)
# 1        20.7783              0                     0.25
# 2        20.7782              5                     0.43
# 3        20.7762             10                     1.19
# 4        20.7779             14                     3.03
# 5        20.7761             18                     7.28
# 6        20.7762             22                    15.68
# 7        20.7733           26.5                    35.44
# 8        20.7753             30                     37.2
# 9        20.7718             32                     37.8
# 10       20.7712             34                    43.32
# 11       20.7721             36                     49.9
# 12       20.7712             38                     43.6
# 13       20.7682             41                     54.4
# 14       20.7701             44                    65.04
# 15       20.7702             47                    73.28
# 16       20.7693             50                     73.2
# 17       20.7666             53                    81.92
# 18       20.7653             56                    84.96
# 19       20.7646             59                    92.96
# 20       20.7669             65                      102
# 21       20.7655             68                   106.44
# 22       20.7630             71                   111.84
# 23       20.7621             74                    119.8
# 24       20.7645            NaN                      NaN
# 25       20.7624            NaN                      NaN
# 26       20.7617            NaN                      NaN
# 27       20.7608            NaN                      NaN
# 28       20.7622            NaN                      NaN
# 29       20.7606            NaN                      NaN
# ...          ...            ...                      ...
# 20813    19.1561            NaN                      NaN
# 20814    19.1556            NaN                      NaN
# 20815    19.1560            NaN                      NaN
# 20816    19.1510            NaN                      NaN
# 20817    19.1522            NaN                      NaN
# 20818    19.1501            NaN                      NaN
# 20819    19.1459            NaN                      NaN
# 20820    19.1439            NaN                      NaN
# 20821    19.1420            NaN                      NaN
# 20822    19.1418            NaN                      NaN
# 20823    19.1396            NaN                      NaN
# 20824    19.1378            NaN                      NaN
# 20825    19.1387            NaN                      NaN
# 20826    19.1389            NaN                      NaN
# 20827    19.1359            NaN                      NaN
# 20828    19.1346            NaN                      NaN
# 20829    19.1335            NaN                      NaN
# 20830    19.1336            NaN                      NaN
# 20831    19.1327            NaN                      NaN
# 20832    19.1337            NaN                      NaN
# 20833    19.1340            NaN                      NaN
# 20834    19.1345            NaN                      NaN
# 20835    19.1347            NaN                      NaN
# 20836    19.1328            NaN                      NaN
# 20837    19.1358            NaN                      NaN
# 20838    19.1358            NaN                      NaN
# 20839    19.1377            NaN                      NaN
# 20840    19.1378            NaN                      NaN
# 20841    19.1399            NaN                      NaN
# 20842    19.1407            NaN                      NaN
#
#                  Unnamed: 9 Unnamed: 10
# 0      Product titer (mg/L)    Time (h)
# 1                     17.63          28
# 2                     46.06          32
# 3                    102.09          36
# 4                     191.2          40
# 5                    215.62          44
# 6                    247.12          48
# 7                    299.72          52
# 8                    310.26        58.5
# 9                    320.29          67
# 10                   384.24          74
# 11                      NaN         NaN
# 12                      NaN         NaN
# 13                      NaN         NaN
# 14                      NaN         NaN
# 15                      NaN         NaN
# 16                      NaN         NaN
# 17                      NaN         NaN
# 18                      NaN         NaN
# 19                      NaN         NaN
# 20                      NaN         NaN
# 21                      NaN         NaN
# 22                      NaN         NaN
# 23                      NaN         NaN
# 24                      NaN         NaN
# 25                      NaN         NaN
# 26                      NaN         NaN
# 27                      NaN         NaN
# 28                      NaN         NaN
# 29                      NaN         NaN
# ...                     ...         ...
# 20813                   NaN         NaN
# 20814                   NaN         NaN
# 20815                   NaN         NaN
# 20816                   NaN         NaN
# 20817                   NaN         NaN
# 20818                   NaN         NaN
# 20819                   NaN         NaN
# 20820                   NaN         NaN
# 20821                   NaN         NaN
# 20822                   NaN         NaN
# 20823                   NaN         NaN
# 20824                   NaN         NaN
# 20825                   NaN         NaN
# 20826                   NaN         NaN
# 20827                   NaN         NaN
# 20828                   NaN         NaN
# 20829                   NaN         NaN
# 20830                   NaN         NaN
# 20831                   NaN         NaN
# 20832                   NaN         NaN
# 20833                   NaN         NaN
# 20834                   NaN         NaN
# 20835                   NaN         NaN
# 20836                   NaN         NaN
# 20837                   NaN         NaN
# 20838                   NaN         NaN
# 20839                   NaN         NaN
# 20840                   NaN         NaN
# 20841                   NaN         NaN
# 20842                   NaN         NaN
#
# [20843 rows x 11 columns]

# %%
testd['Actual CO2']=testd['Actual CO2']*5
testd['Actual O2']=testd['Actual O2']+1.5

# %%
X_new=testd[['Temperature','DO %','Ph','Actual CO2','Actual O2']]

# %%
test_pred_tree = reg2.predict(X_new)

# %%
plt.plot(testd['Time (h)'],test_pred_tree,label='Actual Biomass Conc',color='orange')
plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")
#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')

plt.xlabel("Time in Hours ")
plt.ylabel("Biomass Concentration ( g / L )")
plt.legend()
plt.title("Gradient Boosting Regressor")
# Out:
# Text(0.5,1,'Gradient Boosting Regressor')

# %%
test_pred_ada = adaboost.predict(X_new)

# %%
#plt.plot(temp['Time (h)'],y,label='Actual Biomass',color='red')

plt.plot(testd['Time (h)'],test_pred_ada,label='Predicted Biomass Conc',color='red')
plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")

#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')

plt.xlabel("Time in Hours ")
plt.ylabel("Biomass Concentration ( g / L )")
plt.legend()
plt.title("Adaboost Regressor")
# Out:
# Text(0.5,1,'Adaboost Regressor')

# %%
plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],color='blue',label="Offline Values")

# %%
from sklearn.tree import DecisionTreeRegressor
mod = DecisionTreeRegressor(max_depth=200)
x=pd.DataFrame(testd['Offline Values'][1:24])
y=pd.DataFrame(testd['Unnamed: 8'][1:24])
x_new = x.values.reshape(1,-1)
y_new = y.values.reshape(1,-1)

mod.fit(x,y)
# Out:
# DecisionTreeRegressor(max_depth=200)

# %%
mod.score(x,y)
# Out:
# 1.0

# %%
out2 = mod.predict(testd[['Time (h)']])

# %%
plt.plot(testd['Time (h)'],out2)
plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X_new, out2, test_size=0.1, random_state=42)


print("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %%
reg2 = fit_model(X_train, y_train)
print("Parameter 'max_depth' is {} for the optimal model.".format(reg2.get_params()['max_depth']))
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass scoring=make_scorer(performance_metric) as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Parameter 'max_depth' is 25 for the optimal model.

# %%
reg2.score(X_train, y_train)
# Out:
# 0.999999966818586

# %%
reg2.score(X_test,y_test)
# Out:
# 0.9996756775754648

# %%
pred_tree = reg2.predict(X_new)

# %%
plt.plot(testd['Time (h)'],pred_tree,label='Predicted Biomass Conc',color='black',alpha=1)
#plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,'o',color='blue',label="Offline Values")
plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")


#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')
plt.xlabel("Time in Hours ")
plt.ylabel("Biomass Concentration ( g / L )")
plt.legend()
plt.title("Decision Tree Regressor")
# Out:
# Text(0.5,1,'Decision Tree Regressor')

# %%
from sklearn.ensemble import GradientBoostingRegressor
model1=GradientBoostingRegressor(criterion='mse',max_depth=50)

# %%
model1.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(criterion='mse', max_depth=50)

# %%
model1.score(X_train,y_train)
# Out:
# 0.9999999992944921

# %%
model1.score(X_test,y_test)
# Out:
# 0.999696027241274

# %%
pred = model1.predict(X_test)

# %%
pred2 = model1.predict(X)

# %%
plt.plot(testd['Time (h)'],pred2,label='Predicted Biomass ',color='orange')
#plt.plot(temp['Time (h)'],y,label='Actual Biomass Conc',color='orange')
#plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,'-o',color='blue',label="Offline Values")
#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')
plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")

plt.xlabel("Time in Hours ")
plt.ylabel("Biomass Concentration ( g / L )")
plt.legend()
plt.title("Gradient Boosting Regressor")
# Out:
# Text(0.5,1,'Gradient Boosting Regressor')

# %%
from sklearn.ensemble import AdaBoostRegressor
adaboost=AdaBoostRegressor(DecisionTreeRegressor(max_depth=26),n_estimators=50)

# %%
adaboost.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=26))

# %%
adaboost.score(X_train,y_train)
# Out:
# 0.9999999230524025

# %%
adaboost.score(X_test,y_test)
# Out:
# 0.9995094855961301

# %%
yhat = adaboost.predict(X_test)

# %%
pred_ada = adaboost.predict(X)

# %%
#plt.plot(temp['Time (h)'],y,label='Actual Biomass',color='red')

plt.plot(testd['Time (h)'],pred_ada,label='Predicted Biomass Conc',color='red')
#plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,'-o',color='blue',label="Offline Values")
plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")

#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')

plt.xlabel("Time in Hours ")
plt.ylabel("Biomass Concentration ( g / L )")
plt.legend()
plt.title("Adaboost Regressor")
# Out:
# Text(0.5,1,'Adaboost Regressor')
