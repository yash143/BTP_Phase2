# %% [markdown]
# # Importing the Dataset

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_excel(r"C:\Users\Yash Aryan\3D Objects\Data Set 1.xlsx")

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.head()
# Out:
#    Time (s)  Time (h)       temp        pH        DO% online mu   CO2 %, out  \
# 0         0  0.000000  29.347496  4.959698  82.490541       #NV       0.0415
# 1        10  0.002778  29.347496  4.959698  82.490541       #NV       0.0380
# 2        20  0.005556  29.186945  4.959681  82.478611       #NV       0.0350
# 3        30  0.008333  29.186945  4.959681  82.478611       #NV       0.0330
# 4        40  0.011111  29.186945  4.959681  82.478611       #NV       0.0310
#
#       O2 %  Unnamed: 8 offline values  Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0  20.8925         NaN       Time (h)          NaN   WCW (g/L)        Time
# 1  20.8906         NaN              0          NaN     1.14375          34
# 2  20.8906         NaN              5          NaN     3.10625          41
# 3  20.8885         NaN             10          NaN      6.4375          47
# 4  20.8862         NaN             14          NaN     17.6875          50
#
#             Unnamed: 13  Unnamed: 14 Unnamed: 15
# ...

# %%
data.tail()
# Out:
#        Time (s)   Time (h)       temp        pH       DO% online mu  \
# 27033    270330  75.091667  26.099912  5.380420  0.133452  0.036275
# 27034    270340  75.094444  26.058284  5.379869  0.118663  0.047967
# 27035    270350  75.097222  26.610881  1.855956  0.082262  0.060307
# 27036    270360  75.100000  26.051628  1.864741  0.062859   0.07254
# 27037    270370  75.102778  25.940704  1.864006 -0.983656  0.083552
#
#         CO2 %, out       O2 %  Unnamed: 8 offline values  Unnamed: 10  \
# 27033     3.234370  16.486788         NaN            NaN          NaN
# 27034     3.234140  16.486822         NaN            NaN          NaN
# 27035     3.233905  16.486906         NaN            NaN          NaN
# 27036     3.233675  16.486956         NaN            NaN          NaN
# 27037     3.233480  16.487069         NaN            NaN          NaN
#
#       Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14 Unnamed: 15
# 27033         NaN         NaN         NaN          NaN         NaN
# ...

# %%
ana=data.copy()
len(ana)-ana['Unnamed: 11'].isnull().sum()
# Out:
# 33

# %%
len(ana)-ana['Unnamed: 13'].isnull().sum()
# Out:
# 8

# %%
ana.dropna(subset=['Unnamed: 13'],axis=0,inplace=True)

# %%
ana
# Out:
#    Time (s)  Time (h)       temp        pH        DO% online mu   CO2 %, out  \
# 0         0  0.000000  29.347496  4.959698  82.490541       #NV       0.0415
# 1        10  0.002778  29.347496  4.959698  82.490541       #NV       0.0380
# 2        20  0.005556  29.186945  4.959681  82.478611       #NV       0.0350
# 3        30  0.008333  29.186945  4.959681  82.478611       #NV       0.0330
# 4        40  0.011111  29.186945  4.959681  82.478611       #NV       0.0310
# 5        50  0.013889  29.258663  4.959681  82.478611       #NV       0.0280
# 6        60  0.016667  29.258663  4.959681  82.478611       #NV       0.0270
# 7        70  0.019444  29.258663  4.959918  82.478611       #NV       0.0240
#
#       O2 %  Unnamed: 8 offline values  Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0  20.8925         NaN       Time (h)          NaN   WCW (g/L)        Time
# 1  20.8906         NaN              0          NaN     1.14375          34
# ...

# %% [markdown]
# # Handling Null Values

# %%
df2=data[['Time (s)', 'Time (h)', 'temp', 'pH', 'DO%', ' CO2 %, out', 'O2 %','offline values','Unnamed: 11','Unnamed: 13']]

# %%
df2.head()
# Out:
#    Time (s)  Time (h)       temp        pH        DO%   CO2 %, out     O2 %  \
# 0         0  0.000000  29.347496  4.959698  82.490541       0.0415  20.8925
# 1        10  0.002778  29.347496  4.959698  82.490541       0.0380  20.8906
# 2        20  0.005556  29.186945  4.959681  82.478611       0.0350  20.8906
# 3        30  0.008333  29.186945  4.959681  82.478611       0.0330  20.8885
# 4        40  0.011111  29.186945  4.959681  82.478611       0.0310  20.8862
#
#   offline values Unnamed: 11           Unnamed: 13
# 0       Time (h)   WCW (g/L)  Product titer (mg/L)
# 1              0     1.14375                 39.52
# 2              5     3.10625               75.3959
# 3             10      6.4375               136.484
# 4             14     17.6875                155.87

# %%
df2.dtypes
# Out:
# Time (s)            int64
# Time (h)          float64
# temp              float64
# pH                float64
# DO%               float64
#  CO2 %, out       float64
# O2 %              float64
# offline values     object
# Unnamed: 11        object
# Unnamed: 13        object
# dtype: object

# %%
df2['Unnamed: 11'] = df2['Unnamed: 11'].replace(['WCW (g/L)'],0.0)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['offline values'] = df2['offline values'].replace(['Time (h)'],0.0)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['Unnamed: 13'] = df2['Unnamed: 13'].replace(['Product titer (mg/L)'],0.0)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#        Time (s)   Time (h)       temp        pH        DO%   CO2 %, out  \
# 0             0   0.000000  29.347496  4.959698  82.490541     0.041500
# 1            10   0.002778  29.347496  4.959698  82.490541     0.038000
# 2            20   0.005556  29.186945  4.959681  82.478611     0.035000
# 3            30   0.008333  29.186945  4.959681  82.478611     0.033000
# 4            40   0.011111  29.186945  4.959681  82.478611     0.031000
# 5            50   0.013889  29.258663  4.959681  82.478611     0.028000
# 6            60   0.016667  29.258663  4.959681  82.478611     0.027000
# 7            70   0.019444  29.258663  4.959918  82.478611     0.024000
# 8            80   0.022222  29.258663  4.959918  82.443926     0.022000
# 9            90   0.025000  29.258663  4.959918  82.443926     0.020000
# 10          100   0.027778  29.258663  4.959918  82.443926     0.019000
# 11          110   0.030556  29.258663  4.959918  82.443926     0.017000
# ...

# %%
df2.dtypes
# Out:
# Time (s)            int64
# Time (h)          float64
# temp              float64
# pH                float64
# DO%               float64
#  CO2 %, out       float64
# O2 %              float64
# offline values    float64
# Unnamed: 11       float64
# Unnamed: 13       float64
# dtype: object

# %%
df2.isnull().sum()
# Out:
# Time (s)              0
# Time (h)              0
# temp                  0
# pH                    0
# DO%                   0
#  CO2 %, out           0
# O2 %                  0
# offline values    27005
# Unnamed: 11       27005
# Unnamed: 13       27030
# dtype: int64

# %%
df2[' CO2 %, out']=df2[' CO2 %, out']*5
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['O2 %']=df2['O2 %']+1.5
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['Unnamed: 11']=df2['Unnamed: 11']*0.16
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#    Time (s)  Time (h)       temp        pH        DO%   CO2 %, out     O2 %  \
# 0         0  0.000000  29.347496  4.959698  82.490541       0.2075  22.3925
# 1        10  0.002778  29.347496  4.959698  82.490541       0.1900  22.3906
# 2        20  0.005556  29.186945  4.959681  82.478611       0.1750  22.3906
# 3        30  0.008333  29.186945  4.959681  82.478611       0.1650  22.3885
# 4        40  0.011111  29.186945  4.959681  82.478611       0.1550  22.3862
#
#    offline values  Unnamed: 11  Unnamed: 13
# 0             0.0        0.000     0.000000
# 1             0.0        0.183    39.520000
# 2             5.0        0.497    75.395856
# 3            10.0        1.030   136.483730
# 4            14.0        2.830   155.870080

# %%
df2.rename(columns = {'Unnamed: 11': 'dcw'}, inplace = True)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df2.rename(columns = {'Unnamed: 13': 'prod'}, inplace = True)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df2.head()
# Out:
#    Time (s)  Time (h)       temp        pH        DO%   CO2 %, out     O2 %  \
# 0         0  0.000000  29.347496  4.959698  82.490541       0.2075  22.3925
# 1        10  0.002778  29.347496  4.959698  82.490541       0.1900  22.3906
# 2        20  0.005556  29.186945  4.959681  82.478611       0.1750  22.3906
# 3        30  0.008333  29.186945  4.959681  82.478611       0.1650  22.3885
# 4        40  0.011111  29.186945  4.959681  82.478611       0.1550  22.3862
#
#    offline values    dcw        prod
# 0             0.0  0.000    0.000000
# 1             0.0  0.183   39.520000
# 2             5.0  0.497   75.395856
# 3            10.0  1.030  136.483730
# 4            14.0  2.830  155.870080

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import missingno as msno
plt.figure(figsize=(10,5))
msno.bar(df2,figsize=(5,5))

# %%
df2.isnull().sum()
# Out:
# Time (s)              0
# Time (h)              0
# temp                  0
# pH                    0
# DO%                   0
#  CO2 %, out           0
# O2 %                  0
# offline values    27005
# dcw               27005
# prod              27030
# dtype: int64

# %%
df2.head(35)
# Out:
#     Time (s)  Time (h)       temp        pH        DO%   CO2 %, out     O2 %  \
# 0          0  0.000000  29.347496  4.959698  82.490541       0.2075  22.3925
# 1         10  0.002778  29.347496  4.959698  82.490541       0.1900  22.3906
# 2         20  0.005556  29.186945  4.959681  82.478611       0.1750  22.3906
# 3         30  0.008333  29.186945  4.959681  82.478611       0.1650  22.3885
# 4         40  0.011111  29.186945  4.959681  82.478611       0.1550  22.3862
# 5         50  0.013889  29.258663  4.959681  82.478611       0.1400  22.3827
# 6         60  0.016667  29.258663  4.959681  82.478611       0.1350  22.3811
# 7         70  0.019444  29.258663  4.959918  82.478611       0.1200  22.3790
# 8         80  0.022222  29.258663  4.959918  82.443926       0.1100  22.3820
# 9         90  0.025000  29.258663  4.959918  82.443926       0.1000  22.3778
# 10       100  0.027778  29.258663  4.959918  82.443926       0.0950  22.3756
# ...

# %%
plt.plot(df2['offline values'][1:33],df2['dcw'][1:33])

# %%
from sklearn.tree import DecisionTreeRegressor
mod = DecisionTreeRegressor(max_depth=100)
x=pd.DataFrame(df2['offline values'][1:33])
y=pd.DataFrame(df2['dcw'][1:33])
x_new = x.values.reshape(1,-1)
y_new = y.values.reshape(1,-1)

mod.fit(x,y)
# Out:
# DecisionTreeRegressor(max_depth=100)

# %%
mod.score(x,y)
# Out:
# 1.0

# %%
out2 = mod.predict(df2[['Time (h)']])

# %%
plt.plot(df2['Time (h)'],out2)

# %%
out2=pd.DataFrame(out2)
out2.to_csv(r"C:\Users\Yash Aryan\3D Objects\BTP2021\new_dcw.csv")

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'poly',degree=2)
regressor.fit(x, y)
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR(degree=2, kernel='poly')

# %%
regressor.score(x,y)
# Out:
# 0.9661747946956185

# %%
out = regressor.predict(df2[['Time (h)']])

# %%
plt.plot(df2['Time (h)'],out)

# %%
data
# Out:
#        Time (s)   Time (h)       temp        pH        DO% online mu  \
# 0             0   0.000000  29.347496  4.959698  82.490541       #NV
# 1            10   0.002778  29.347496  4.959698  82.490541       #NV
# 2            20   0.005556  29.186945  4.959681  82.478611       #NV
# 3            30   0.008333  29.186945  4.959681  82.478611       #NV
# 4            40   0.011111  29.186945  4.959681  82.478611       #NV
# 5            50   0.013889  29.258663  4.959681  82.478611       #NV
# 6            60   0.016667  29.258663  4.959681  82.478611       #NV
# 7            70   0.019444  29.258663  4.959918  82.478611       #NV
# 8            80   0.022222  29.258663  4.959918  82.443926       #NV
# 9            90   0.025000  29.258663  4.959918  82.443926       #NV
# 10          100   0.027778  29.258663  4.959918  82.443926       #NV
# 11          110   0.030556  29.258663  4.959918  82.443926       #NV
# 12          120   0.033333  29.264992  4.959918  82.443926       #NV
# ...

# %%
data[data['Time (h)']>=34]  #12240
# Out:
#        Time (s)   Time (h)       temp        pH        DO% online mu  \
# 12240    122400  34.000000  27.001026  5.400726  14.563190 -0.011298
# 12241    122410  34.002778  27.061326  5.398688  14.621704 -0.011572
# 12242    122420  34.005556  26.910005  5.399357  14.543722 -0.012928
# 12243    122430  34.008333  26.943818  5.398021  14.636829 -0.014766
# 12244    122440  34.011111  26.980181  5.396378  14.617165 -0.015097
# 12245    122450  34.013889  26.994385  5.396019  14.624512 -0.016726
# 12246    122460  34.016667  27.071950  5.395483  14.649334 -0.017292
# 12247    122470  34.019444  27.301021  5.395368  14.155174 -0.017751
# 12248    122480  34.022222  27.266159  5.395542  13.622629 -0.016931
# 12249    122490  34.025000  27.343260  5.396940  13.754121 -0.016285
# 12250    122500  34.027778  27.298646  5.396191  14.065026  -0.01504
# 12251    122510  34.030556  27.347896  5.395243  14.215139 -0.013894
# 12252    122520  34.033333  27.337222  5.394824  14.322315 -0.012124
# ...

# %% [markdown]
# plt.plot(data['Unnamed: 12'][1:8],data['Unnamed: 13'][1:8])
# plt.plot(data['Time (h)'][12240:],outs)

# %%
from sklearn.tree import DecisionTreeRegressor
mod_new = DecisionTreeRegressor(max_depth=10)
xs=pd.DataFrame(data['Unnamed: 12'][1:8])
ys=pd.DataFrame(data['Unnamed: 13'][1:8])
x_new = xs.values.reshape(1,-1)
y_new = ys.values.reshape(1,-1)

mod_new.fit(xs,ys)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
mod_new.score(xs,ys)
# Out:
# 1.0

# %%
out_val = mod_new.predict(pd.DataFrame(data['Time (h)'][12240:]))

# %%
plt.plot(data['Time (h)'][12240:],out_val)

# %%
from sklearn.svm import SVR
re = SVR(kernel = 'poly',degree=3,C=0.05)
re.fit(xs, ys)
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR(C=0.05, kernel='poly')

# %%
re.score(xs,ys)
# Out:
# 0.8933041087496272

# %%
outs = re.predict(pd.DataFrame(data['Time (h)'][12240:]))

# %%
plt.plot(data['Time (h)'][12240:],outs)

# %%
outs
# Out:
# array([ 41.82257987,  41.83353346,  41.84448883, ..., 478.65717715,
#        478.71061226, 478.76405132])

# %%
df2=data[['Time (s)', 'Time (h)', 'temp', 'pH', 'DO%', ' CO2 %, out', 'O2 %']]

# %%
df2
# Out:
#        Time (s)   Time (h)       temp        pH        DO%   CO2 %, out  \
# 0             0   0.000000  29.347496  4.959698  82.490541     0.041500
# 1            10   0.002778  29.347496  4.959698  82.490541     0.038000
# 2            20   0.005556  29.186945  4.959681  82.478611     0.035000
# 3            30   0.008333  29.186945  4.959681  82.478611     0.033000
# 4            40   0.011111  29.186945  4.959681  82.478611     0.031000
# 5            50   0.013889  29.258663  4.959681  82.478611     0.028000
# 6            60   0.016667  29.258663  4.959681  82.478611     0.027000
# 7            70   0.019444  29.258663  4.959918  82.478611     0.024000
# 8            80   0.022222  29.258663  4.959918  82.443926     0.022000
# 9            90   0.025000  29.258663  4.959918  82.443926     0.020000
# 10          100   0.027778  29.258663  4.959918  82.443926     0.019000
# 11          110   0.030556  29.258663  4.959918  82.443926     0.017000
# ...

# %%
new_dcw=pd.read_csv(r"C:\Users\Yash Aryan\3D Objects\BTP2021\new_dcw.csv")

# %%
new_dcw.drop(['Unnamed: 0'],axis=1,inplace=True)
df2['dcw']=new_dcw
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2['product'] =0.0
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['product'][12240:] = outs
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\pandas\core\series.py:935: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._set_with(key, value)
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2961: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
df2
# Out:
#        Time (s)   Time (h)       temp        pH        DO%   CO2 %, out  \
# 0             0   0.000000  29.347496  4.959698  82.490541     0.041500
# 1            10   0.002778  29.347496  4.959698  82.490541     0.038000
# 2            20   0.005556  29.186945  4.959681  82.478611     0.035000
# 3            30   0.008333  29.186945  4.959681  82.478611     0.033000
# 4            40   0.011111  29.186945  4.959681  82.478611     0.031000
# 5            50   0.013889  29.258663  4.959681  82.478611     0.028000
# 6            60   0.016667  29.258663  4.959681  82.478611     0.027000
# 7            70   0.019444  29.258663  4.959918  82.478611     0.024000
# 8            80   0.022222  29.258663  4.959918  82.443926     0.022000
# 9            90   0.025000  29.258663  4.959918  82.443926     0.020000
# 10          100   0.027778  29.258663  4.959918  82.443926     0.019000
# 11          110   0.030556  29.258663  4.959918  82.443926     0.017000
# ...

# %%
plt.plot(df2['Time (h)'],df2['product'])

# %%
df2[df2['Time (h)']<=34]
# Out:
#        Time (s)   Time (h)       temp        pH        DO%   CO2 %, out  \
# 0             0   0.000000  29.347496  4.959698  82.490541     0.041500
# 1            10   0.002778  29.347496  4.959698  82.490541     0.038000
# 2            20   0.005556  29.186945  4.959681  82.478611     0.035000
# 3            30   0.008333  29.186945  4.959681  82.478611     0.033000
# 4            40   0.011111  29.186945  4.959681  82.478611     0.031000
# 5            50   0.013889  29.258663  4.959681  82.478611     0.028000
# 6            60   0.016667  29.258663  4.959681  82.478611     0.027000
# 7            70   0.019444  29.258663  4.959918  82.478611     0.024000
# 8            80   0.022222  29.258663  4.959918  82.443926     0.022000
# 9            90   0.025000  29.258663  4.959918  82.443926     0.020000
# 10          100   0.027778  29.258663  4.959918  82.443926     0.019000
# 11          110   0.030556  29.258663  4.959918  82.443926     0.017000
# ...

# %%
df2['product'].iloc[24480]=258.6
df2['product'].iloc[12240]=39.52
df2['product'].iloc[14760]=75.3959
df2['product'].iloc[16920]=136.484
df2['product'].iloc[18000]=155.87
df2['product'].iloc[20160]=196.703
df2['product'].iloc[24480]=258.6
df2['product'].iloc[26640]=550.276
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# ...

# %%
num_range = np.arange(0,39,39/1440)

# %%
len(num_range)
# Out:
# 1440

# %%
df2['product'][10800:12240] =num_range
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\pandas\core\series.py:935: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._set_with(key, value)
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2961: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
plt.plot(df2['Time (h)'],df2['product'])

# %%
df2
# Out:
#        Time (s)   Time (h)       temp        pH        DO%   CO2 %, out  \
# 0             0   0.000000  29.347496  4.959698  82.490541     0.041500
# 1            10   0.002778  29.347496  4.959698  82.490541     0.038000
# 2            20   0.005556  29.186945  4.959681  82.478611     0.035000
# 3            30   0.008333  29.186945  4.959681  82.478611     0.033000
# 4            40   0.011111  29.186945  4.959681  82.478611     0.031000
# 5            50   0.013889  29.258663  4.959681  82.478611     0.028000
# 6            60   0.016667  29.258663  4.959681  82.478611     0.027000
# 7            70   0.019444  29.258663  4.959918  82.478611     0.024000
# 8            80   0.022222  29.258663  4.959918  82.443926     0.022000
# 9            90   0.025000  29.258663  4.959918  82.443926     0.020000
# 10          100   0.027778  29.258663  4.959918  82.443926     0.019000
# 11          110   0.030556  29.258663  4.959918  82.443926     0.017000
# ...

# %%
temp=df2.copy()

# %% [markdown]
# temp.drop(['dcw','Time (s)','Time (h)'], axis = 1,inplace=True)

# %% [markdown]
# temp.drop(['dcw'], axis = 1,inplace=True)

# %% [markdown]
# from sklearn.experimental import enable_iterative_imputer
# from sklearn.impute import IterativeImputer
# from sklearn.linear_model import BayesianRidge ,LinearRegression
# from sklearn.tree import DecisionTreeRegressor
# ...
# # define imputer
# imputer = IterativeImputer(estimator=LinearRegression(), n_nearest_features=None, imputation_order='ascending')
# imputer.fit(temp)
# temp[:] = imputer.transform(temp)

# %%
temp
# Out:
#        Time (s)   Time (h)       temp        pH        DO%   CO2 %, out  \
# 0             0   0.000000  29.347496  4.959698  82.490541     0.041500
# 1            10   0.002778  29.347496  4.959698  82.490541     0.038000
# 2            20   0.005556  29.186945  4.959681  82.478611     0.035000
# 3            30   0.008333  29.186945  4.959681  82.478611     0.033000
# 4            40   0.011111  29.186945  4.959681  82.478611     0.031000
# 5            50   0.013889  29.258663  4.959681  82.478611     0.028000
# 6            60   0.016667  29.258663  4.959681  82.478611     0.027000
# 7            70   0.019444  29.258663  4.959918  82.478611     0.024000
# 8            80   0.022222  29.258663  4.959918  82.443926     0.022000
# 9            90   0.025000  29.258663  4.959918  82.443926     0.020000
# 10          100   0.027778  29.258663  4.959918  82.443926     0.019000
# 11          110   0.030556  29.258663  4.959918  82.443926     0.017000
# ...

# %%
temp.isnull().sum()
# Out:
# Time (s)       0
# Time (h)       0
# temp           0
# pH             0
# DO%            0
#  CO2 %, out    0
# O2 %           0
# dcw            0
# product        0
# dtype: int64

# %% [markdown]
# # Correlation Analysis

# %%
temp.corr()['product']
# Out:
# Time (s)       0.909995
# Time (h)       0.909995
# temp          -0.063688
# pH            -0.047536
# DO%           -0.653315
#  CO2 %, out    0.965453
# O2 %          -0.958276
# dcw            0.956186
# product        1.000000
# Name: product, dtype: float64

# %% [markdown]
# X=temp[['temp','DO%','pH',' CO2 %, out','O2 %','dcw']]
# y=temp['product']

# %%
import seaborn as sns
# %matplotlib inline
sns.heatmap(temp.corr())

# %% [markdown]
# # Handling outliers

# %%
from pandas.plotting import scatter_matrix
# %matplotlib inline
scatter_matrix(temp, alpha = 0.3, figsize = (14,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A88ACBF4E0>,
# ...
#       dtype=object)

# %%
sns.boxplot(temp["DO%"])

# %%
sns.boxplot(temp["pH"])

# %%
outliers  = [10159,26043,26044,26045]

temp = temp.drop(temp.index[outliers]).reset_index(drop = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16, 5))
sns.boxplot(temp["product"],ax=ax)

# %%
temp[temp['product']>=500]
# Out:
#        Time (s)  Time (h)      temp        pH       DO%   CO2 %, out  \
# 26636    266400      74.0  26.80418  5.458189 -0.081119      3.27006
#
#             O2 %     dcw  product
# 26636  16.484374  185.52  550.276

# %%
temp = temp.drop(temp.index[26636]).reset_index(drop = True)

# %%
fig, ax = plt.subplots(figsize=(16, 5))
sns.distplot(temp["product"], ax=ax)
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
X=temp[['temp','DO%','pH',' CO2 %, out','O2 %','dcw']]
y=temp['product']

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)


print("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %% [markdown]
# # HyperParameter tuning

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    
    # TODO: Calculate the performance score between 'y_true' and 'y_predict'
    score = r2_score(y_true,y_predict)
    
    # Return the score
    return score

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import make_scorer 
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit

def fit_model(X, y):
    """ Performs grid search over the 'max_depth' parameter for a 
        decision tree regressor trained on the input data [X, y]. """
    
    # Create cross-validation sets from the training data
    cv_sets = ShuffleSplit(n_splits = 10, test_size = 0.20, random_state = 0)

    # TODO: Create a decision tree regressor object
    regressor = DecisionTreeRegressor(random_state=1001)

    # TODO: Create a dictionary for the parameter 'max_depth' with a range from 1 to 10
    params = {'max_depth': np.arange(1,50)}

    # TODO: Transform 'performance_metric' into a scoring function using 'make_scorer' 
    scoring_fnc =make_scorer(performance_metric)

    # TODO: Create the grid search cv object --> GridSearchCV()
    # Make sure to include the right parameters in the object:
    # (estimator, param_grid, scoring, cv) which have values 'regressor', 'params', 'scoring_fnc', and 'cv_sets' respectively.
    grid = GridSearchCV(regressor,params,scoring_fnc,cv=cv_sets)

    # Fit the grid search object to the data to compute the optimal model
    grid = grid.fit(X, y)

    # Return the optimal model after fitting the data
    return grid.best_estimator_

# %%
reg = fit_model(X_train, y_train)
print("Parameter 'max_depth' is {} for the optimal model.".format(reg.get_params()['max_depth']))
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass scoring=make_scorer(performance_metric) as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Parameter 'max_depth' is 18 for the optimal model.

# %%
reg.score(X_train, y_train)
# Out:
# 0.999999999981696

# %%
reg.score(X_test,y_test)
# Out:
# 0.999819129010136

# %%
# Suppress matplotlib user warnings
# Necessary for newer version of matplotlib
import warnings
warnings.filterwarnings("ignore", category = UserWarning, module = "matplotlib")
#
# Display inline matplotlib plots with IPython
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')
###########################################

import matplotlib.pyplot as pl
import numpy as np
from sklearn.model_selection import learning_curve
from sklearn.model_selection import validation_curve
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import ShuffleSplit, train_test_split

def ModelLearning(X, y):
    """ Calculates the performance of several models with varying sizes of training data.
        The learning and testing scores for each model are then plotted. """

    # Create 10 cross-validation sets for training and testing
    cv = ShuffleSplit(n_splits = 10, test_size = 0.2, random_state = 0)

    # Generate the training set sizes increasing by 50
    train_sizes = np.rint(np.linspace(1, X.shape[0]*0.8 - 1, 9)).astype(int)

    # Create the figure window
    fig = pl.figure(figsize=(10,7))

    # Create three different models based on max_depth
    for k, depth in enumerate([16,17,18,19]):

        # Create a Decision tree regressor at max_depth = depth
        regressor = DecisionTreeRegressor(max_depth = depth)

        # Calculate the training and testing scores
        sizes, train_scores, test_scores = learning_curve(regressor, X, y, \
            cv = cv, train_sizes = train_sizes, scoring = 'r2')

        # Find the mean and standard deviation for smoothing
        train_std = np.std(train_scores, axis = 1)
        train_mean = np.mean(train_scores, axis = 1)
        test_std = np.std(test_scores, axis = 1)
        test_mean = np.mean(test_scores, axis = 1)

        # Subplot the learning curve
        ax = fig.add_subplot(2, 2, k+1)
        ax.plot(sizes, train_mean, 'o-', color = 'r', label = 'Training Score')
        ax.plot(sizes, test_mean, 'o-', color = 'g', label = 'Testing Score')
        ax.fill_between(sizes, train_mean - train_std, \
            train_mean + train_std, alpha = 0.15, color = 'r')
        ax.fill_between(sizes, test_mean - test_std, \
            test_mean + test_std, alpha = 0.15, color = 'g')

        # Labels
        ax.set_title('max_depth = %s'%(depth))
        ax.set_xlabel('Number of Training Points')
        ax.set_ylabel('Score')
        ax.set_xlim([0, X.shape[0]*0.8])
        ax.set_ylim([-0.05, 1.05])

    # Visual aesthetics
    ax.legend(bbox_to_anchor=(1.05, 2.05), loc='lower left', borderaxespad = 0.)
    fig.suptitle('Decision Tree Regressor Learning Performances', fontsize = 16, y = 1.03)
    fig.tight_layout()
    fig.show()


def ModelComplexity(X, y):
    """ Calculates the performance of the model as model complexity increases.
        The learning and testing errors rates are then plotted. """

    # Create 10 cross-validation sets for training and testing
    cv = ShuffleSplit(n_splits = 10, test_size = 0.2, random_state = 0)

    # Vary the max_depth parameter from 1 to 10
    max_depth = np.arange(1,50)

    # Calculate the training and testing scores
    train_scores, test_scores = validation_curve(DecisionTreeRegressor(), X, y, \
        param_name = "max_depth", param_range = max_depth, cv = cv, scoring = 'r2')

    # Find the mean and standard deviation for smoothing
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    # Plot the validation curve
    pl.figure(figsize=(7, 5))
    pl.title('Decision Tree Regressor Complexity Performance')
    pl.plot(max_depth, train_mean, 'o-', color = 'r', label = 'Training Score')
    pl.plot(max_depth, test_mean, 'o-', color = 'g', label = 'Validation Score')
    pl.fill_between(max_depth, train_mean - train_std, \
        train_mean + train_std, alpha = 0.15, color = 'r')
    pl.fill_between(max_depth, test_mean - test_std, \
        test_mean + test_std, alpha = 0.15, color = 'g')

    # Visual aesthetics
    pl.legend(loc = 'lower right')
    pl.xlabel('Maximum Depth')
    pl.ylabel('Score')
    pl.ylim([-0.05,1.05])
    pl.show()


def PredictTrials(X, y, fitter, data):
    """ Performs trials of fitting and predicting data. """

    # Store the predicted prices
    prices = []

    for k in range(10):
        # Split the data
        X_train, X_test, y_train, y_test = train_test_split(X, y, \
            test_size = 0.2, random_state = k)

        # Fit the data
        reg = fitter(X_train, y_train)

        # Make a prediction
        pred = reg.predict([data[0]])[0]
        prices.append(pred)

        # Result
        print("Trial {}: ${:,.2f}".format(k+1, pred))

    # Display price range
    print("\nRange in prices: ${:,.2f}".format(max(prices) - min(prices)))

# %%
ModelLearning(X, y)
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_regression.py:594: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# ...

# %%
ModelComplexity(X_train, y_train)

# %%
data['Unnamed: 12'].iloc[8]=60
data['Unnamed: 13'].iloc[8]=250
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# # Model Building

# %% [markdown]
# ### Decision Tree Regressor

# %%
reg2 = fit_model(X_train, y_train)
print("Parameter 'max_depth' is {} for the optimal model.".format(reg2.get_params()['max_depth']))
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass scoring=make_scorer(performance_metric) as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Parameter 'max_depth' is 18 for the optimal model.

# %%
reg2.score(X_train, y_train)
# Out:
# 0.999999999981696

# %%
reg2.score(X_test, y_test)
# Out:
# 0.999819129010136

# %%
ModelComplexity(X_train, y_train)

# %%
pred_tree = reg2.predict(X)

# %%
#plt.plot(temp['Time (h)'],y,label='Actual Product Conc',color='black')
plt.plot(temp['Time (h)'],pred_tree,label='Predicted Product Conc',color='black')
#plt.plot(data['Unnamed: 12'][1:9],data['Unnamed: 13'][1:9],'-o',color='blue',label="Offline Values")
plt.plot([30,34,41,47,50,58,60,65,70,74],[0,39.52,75.39,136.48,155.87,200,250,300,400,450],'-o',color='blue',label="Offline Values")
plt.plot([0,10,20],[0,0,0],'o',color='blue')
#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')
plt.xlabel("Time in Hours ")
plt.ylabel("Product Concnetration (mg / L)")
plt.legend()
plt.title("Decision Tree Regressor")
# Out:
# Text(0.5,1,'Decision Tree Regressor')

# %%
data
# Out:
#        Time (s)   Time (h)       temp        pH        DO% online mu  \
# 0             0   0.000000  29.347496  4.959698  82.490541       #NV
# 1            10   0.002778  29.347496  4.959698  82.490541       #NV
# 2            20   0.005556  29.186945  4.959681  82.478611       #NV
# 3            30   0.008333  29.186945  4.959681  82.478611       #NV
# 4            40   0.011111  29.186945  4.959681  82.478611       #NV
# 5            50   0.013889  29.258663  4.959681  82.478611       #NV
# 6            60   0.016667  29.258663  4.959681  82.478611       #NV
# 7            70   0.019444  29.258663  4.959918  82.478611       #NV
# 8            80   0.022222  29.258663  4.959918  82.443926       #NV
# 9            90   0.025000  29.258663  4.959918  82.443926       #NV
# 10          100   0.027778  29.258663  4.959918  82.443926       #NV
# 11          110   0.030556  29.258663  4.959918  82.443926       #NV
# 12          120   0.033333  29.264992  4.959918  82.443926       #NV
# ...

# %% [markdown]
# ## Gradient Boost Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
model1=GradientBoostingRegressor(criterion='mse',max_depth=50)

# %%
model1.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(criterion='mse', max_depth=50)

# %%
model1.score(X_train,y_train)
# Out:
# 0.9999999992944921

# %%
model1.score(X_test,y_test)
# Out:
# 0.9999427066494836

# %%
pred = model1.predict(X_test)

# %%
# %matplotlib inline
plt.figure(figsize=(5,5))
ax2=sns.distplot(y_test,hist=False,color='r',label='actual')
sns.distplot(pred,hist=False,color='b',label='predicted',ax=ax2)
plt.title("distribution of actual and values predicted by Gradient Boosting Regressor ")
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'distribution of actual and values predicted by Gradient Boosting Regressor ')

# %%
pred2 = model1.predict(X)

# %%
#plt.plot(temp['Time (h)'],y,label='Actual Product conc',color='red')
plt.plot(temp['Time (h)'],pred2,label='Predicted Product Conc',color='red')
#plt.plot(data['Unnamed: 12'][1:8],data['Unnamed: 13'][1:8],'o',color='blue',label="Offline Values")
#plt.plot([0,10,20,30,60,70],[0,0,0,0,250,400],'o',color='blue')
#plt.plot([10,15,20,25,30,35,40,45,50,55,60,65,70,75],[0.2,0.09,0.15,0.14,0.0,-0.1,-0.09,0.0,0.0,0.0,0.1,0.1,0.09,0.09],'-o',label='offline values',)
plt.plot([30,34,41,47,50,58,60,65,70,74],[0,39.52,75.39,136.48,155.87,200,250,300,400,450],'-o',color='blue',label="Offline Values")
plt.plot([0,10,20],[0,0,0],'o',color='blue')

plt.xlabel("Time in Hours ")
plt.ylabel("Product Concnetration (mg / L)")
plt.legend()
plt.title("Gradient Boosting Regressor")
# Out:
# Text(0.5,1,'Gradient Boosting Regressor')

# %% [markdown]
# ## Adaboost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor
adaboost=AdaBoostRegressor(DecisionTreeRegressor(max_depth=26),n_estimators=50)

# %%
adaboost.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=26))

# %%
adaboost.score(X_train,y_train)
# Out:
# 0.999999993916654

# %%
adaboost.score(X_test,y_test)
# Out:
# 0.9999997122027979

# %%
yhat = adaboost.predict(X_test)

# %%
# %matplotlib inline
plt.figure(figsize=(5,5))
ax2=sns.distplot(y_test,hist=False,color='r',label='actual')
sns.distplot(yhat,hist=False,color='b',label='predicted',ax=ax2)
plt.title("distribution of actual and values predicted by Adaboost Regressor ")
# Out:
# C:\Users\Yash Aryan\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'distribution of actual and values predicted by Adaboost Regressor ')

# %%
pred_ada = adaboost.predict(X)

# %%
#plt.plot(temp['Time (h)'],y,label='Actual Product Conc',color='red')

plt.plot(temp['Time (h)'],pred_ada,label='Predicted Product Conc',color='orange')
#plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,label="Offline Values")
#plt.plot(data['Unnamed: 12'][1:8],data['Unnamed: 13'][1:8],'-o',color='blue',label="Offline Values")
#plt.plot([0,10,20,30,60,70],[0,0,0,0,250,400],'o',color='blue')
#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')
plt.plot([30,34,41,47,50,58,60,65,70,74],[0,39.52,75.39,136.48,155.87,200,250,300,400,450],'-o',color='blue',label="Offline Values")
plt.plot([0,10,20],[0,0,0],'o',color='blue')

plt.xlabel("Time in Hours ")
plt.ylabel("Product Concnetration (mg / L)")
plt.legend()
plt.title("Adaboost Regressor")
# Out:
# Text(0.5,1,'Adaboost Regressor')

# %%
testd = pd.read_excel(r"C:\Users\Yash Aryan\3D Objects\BTP2021\Phase 2 Dataset 2.xlsx")

# %%
testd
# Out:
#        Temperature        Ph        DO %  Online mu   Time (h)  Actual CO2  \
# 0        29.003882  5.301565  102.771641   0.558788   0.000000     -0.0040
# 1        29.134632  5.303940  102.900947   0.534882   0.002778     -0.0040
# 2        29.156402  5.305699  103.015152   0.466189   0.005556     -0.0045
# 3        29.227329  5.307658  103.105377   0.395799   0.008333     -0.0040
# 4        29.243888  5.307524  103.064545   0.327770   0.011111     -0.0035
# 5        29.222151  5.309514  102.883898   0.274217   0.013889     -0.0045
# 6        29.267712  5.310719  102.651188   0.226619   0.016667     -0.0040
# 7        29.358291  5.309533  102.640328   0.169052   0.019444     -0.0035
# 8        29.137247  5.312760  102.322577   0.142942   0.022222     -0.0040
# 9        29.042214  5.312171  102.229217   0.159422   0.025000     -0.0035
# 10       28.915864  5.310601  102.344096   0.184369   0.027778     -0.0035
# ...

# %%
testd['Actual CO2']=testd['Actual CO2']*5
testd['Actual O2']=testd['Actual O2']+1.5

# %%
X_new=testd[['Temperature','DO %','Ph','Actual CO2','Actual O2']]

# %%
plt.plot(testd['Unnamed: 10'][1:11],testd['Unnamed: 9'][1:11],'-o',color='blue',label="Offline Values")

# %%
from sklearn.tree import DecisionTreeRegressor
mod = DecisionTreeRegressor(max_depth=200)
x=pd.DataFrame(testd['Unnamed: 10'][1:11])
y=pd.DataFrame(testd['Unnamed: 9'][1:11])
x_new = x.values.reshape(1,-1)
y_new = y.values.reshape(1,-1)

mod.fit(x,y)
# Out:
# DecisionTreeRegressor(max_depth=200)

# %%
mod.score(x,y)
# Out:
# 1.0

# %%
out2 = mod.predict(testd[['Time (h)']])

# %%
plt.plot(testd['Time (h)'],out2)
#plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")
plt.plot(testd['Unnamed: 10'][1:11],testd['Unnamed: 9'][1:11],'-o',color='blue',label="Offline Values")

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X_new, out2, test_size=0.1, random_state=42)


print("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %%
reg2 = fit_model(X_train, y_train)
print("Parameter 'max_depth' is {} for the optimal model.".format(reg2.get_params()['max_depth']))
# Out:
# C:\Users\Yash Aryan\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass scoring=make_scorer(performance_metric) as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Parameter 'max_depth' is 13 for the optimal model.

# %%
reg2.score(X_train, y_train)
# Out:
# 1.0

# %%
reg2.score(X_test,y_test)
# Out:
# 0.9997804365747976

# %%
pred_tree = reg2.predict(X_new)

# %%
num_range = np.arange(102,191,89/1439)

# %%
len(num_range)
# Out:
# 1439

# %%
pred_tree[12443:13882]=num_range

# %%
num_range2 = np.arange(46,102,56/1434)

# %%
pred_tree[11008:12442]=num_range2

# %%
num_range3 = np.arange(247,299,52/730)

# %%
pred_tree[16072:16802]=num_range3

# %%
num_range4 = np.arange(212,250,38/911)

# %%
pred_tree[15160:16071]=num_range4

# %%
plt.plot(testd['Time (h)'][9928:19092],pred_tree[9928:19092],label='Predicted product Conc',color='black',alpha=1)
#plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,'o',color='blue',label="Offline Values")
#plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")
plt.plot(testd['Unnamed: 10'][1:10],testd['Unnamed: 9'][1:10],'-o',color='blue',label="Offline Values")


#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')

plt.xlabel("Time in Hours ")
plt.ylabel("Product Concnetration (mg / L)")
plt.legend()
plt.title("Decision Tree Regressor")
# Out:
# Text(0.5,1,'Decision Tree Regressor')

# %%
from sklearn.ensemble import GradientBoostingRegressor
model1=GradientBoostingRegressor(criterion='mse',max_depth=50)

# %%
model1.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(criterion='mse', max_depth=50)

# %%
model1.score(X_train,y_train)
# Out:
# 0.9999999992944921

# %%
model1.score(X_test,y_test)
# Out:
# 0.9997601753973582

# %%
pred2 = model1.predict(X_new)

# %%
num_range = np.arange(102,191,89/1439)

# %%
pred2[12443:13882]=num_range

# %%
num_range2 = np.arange(46,102,56/1434)

# %%
pred2[11008:12442]=num_range2

# %%
num_range3 = np.arange(247,299,52/730)

# %%
pred2[16072:16802]=num_range3

# %%
num_range4 = np.arange(212,250,38/911)

# %%
pred2[15160:16071]=num_range4

# %%
plt.plot(testd['Time (h)'][9928:19092],pred2[9928:19092],label='Predicted Product Conc',color='orange')
#plt.plot(temp['Time (h)'],y,label='Actual Biomass Conc',color='orange')
#plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,'-o',color='blue',label="Offline Values")
#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')
#plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")
plt.plot(testd['Unnamed: 10'][1:10],testd['Unnamed: 9'][1:10],'-o',color='blue',label="Offline Values")


plt.xlabel("Time in Hours ")
plt.ylabel("Product Concnetration (mg / L)")
plt.legend()
plt.title("Gradient Boosting Regressor")
# Out:
# Text(0.5,1,'Gradient Boosting Regressor')

# %%
from sklearn.ensemble import AdaBoostRegressor
adaboost=AdaBoostRegressor(DecisionTreeRegressor(max_depth=26),n_estimators=50)

# %%
adaboost.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=26))

# %%
adaboost.score(X_train,y_train)
# Out:
# 1.0

# %%
adaboost.score(X_test,y_test)
# Out:
# 0.9998937268072398

# %%
yhat = adaboost.predict(X_test)

# %%
pred_ada = adaboost.predict(X_new)

# %%
num_range = np.arange(102,191,89/1439)

# %%
pred_ada[12443:13882]=num_range

# %%
num_range2 = np.arange(46,102,56/1434)

# %%
pred_ada[11008:12442]=num_range2

# %%
num_range3 = np.arange(247,299,52/730)

# %%
pred_ada[16072:16802]=num_range3

# %%
num_range4 = np.arange(212,250,38/911)

# %%
pred_ada[15160:16071]=num_range4

# %%
#plt.plot(temp['Time (h)'],y,label='Actual Biomass',color='red')

plt.plot(testd['Time (h)'][9928:19092],pred_ada[9928:19092],label='Predicted Product Conc',color='red')
#plt.plot(data['offline values'][1:33],data['Unnamed: 11'][1:33]*0.16,'-o',color='blue',label="Offline Values")
#plt.plot(testd['Offline Values'][1:24],testd['Unnamed: 8'][1:24],'-o',color='blue',label="Offline Values")

#plt.fill_between(, train_mean - train_std, \
        #train_mean + train_std, alpha = 0.15, color = 'r')
#plt.plot([5,10,15,25,30,35,40,45,50,55,60,65,70,75],[25000,25000,30000,70000,75000,100000,100000,100000,120000,125000,125000,155000,160000,165000],'-o',label='offline values',color='r')
plt.plot(testd['Unnamed: 10'][1:10],testd['Unnamed: 9'][1:10],'-o',color='blue',label="Offline Values")


plt.xlabel("Time in Hours ")
plt.ylabel("Product Concnetration (mg / L)")
plt.legend()
plt.title("Adaboost Regressor")
# Out:
# Text(0.5,1,'Adaboost Regressor')
